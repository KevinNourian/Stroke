# %% [markdown]
# # 01 Stroke Draft

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
stroke = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Stroke\DataSet\\stroke.csv")

# %%
stroke = stroke.rename(
    columns={
        "id": "ID",
        "gender": "Gender",
        "age": "Age",
        "hypertension": "Hypertension",
        "heart_disease": "HeartDisease",
        "ever_married": "EverMarried",
        "work_type": "WorkType",
        "Residence_type": "ResidenceType",
        "avg_glucose_level": "AvgGlucoseLevel",
        "bmi": "BMI",
        "smoking_status": "SmokingStatus",
        "stroke": "Stroke",
        
    }
)

# %%
stroke.head()
# Out:
#       ID  Gender   Age  Hypertension  HeartDisease EverMarried       WorkType  \
# 0   9046    Male  67.0             0             1         Yes        Private
# 1  51676  Female  61.0             0             0         Yes  Self-employed
# 2  31112    Male  80.0             0             1         Yes        Private
# 3  60182  Female  49.0             0             0         Yes        Private
# 4   1665  Female  79.0             1             0         Yes  Self-employed
#
#   ResidenceType  AvgGlucoseLevel   BMI    SmokingStatus  Stroke
# 0         Urban           228.69  36.6  formerly smoked       1
# 1         Rural           202.21   NaN     never smoked       1
# 2         Rural           105.92  32.5     never smoked       1
# 3         Urban           171.23  34.4           smokes       1
# 4         Rural           174.12  24.0     never smoked       1

# %%
stroke.shape[0]
# Out:
# 5110

# %%
stroke.gender.sort_values().unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
stroke.age.sort_values().unique()
# Out:
# array([8.00e-02, 1.60e-01, 2.40e-01, 3.20e-01, 4.00e-01, 4.80e-01,
#        5.60e-01, 6.40e-01, 7.20e-01, 8.00e-01, 8.80e-01, 1.00e+00,
#        1.08e+00, 1.16e+00, 1.24e+00, 1.32e+00, 1.40e+00, 1.48e+00,
#        1.56e+00, 1.64e+00, 1.72e+00, 1.80e+00, 1.88e+00, 2.00e+00,
#        3.00e+00, 4.00e+00, 5.00e+00, 6.00e+00, 7.00e+00, 8.00e+00,
#        9.00e+00, 1.00e+01, 1.10e+01, 1.20e+01, 1.30e+01, 1.40e+01,
#        1.50e+01, 1.60e+01, 1.70e+01, 1.80e+01, 1.90e+01, 2.00e+01,
#        2.10e+01, 2.20e+01, 2.30e+01, 2.40e+01, 2.50e+01, 2.60e+01,
#        2.70e+01, 2.80e+01, 2.90e+01, 3.00e+01, 3.10e+01, 3.20e+01,
#        3.30e+01, 3.40e+01, 3.50e+01, 3.60e+01, 3.70e+01, 3.80e+01,
#        3.90e+01, 4.00e+01, 4.10e+01, 4.20e+01, 4.30e+01, 4.40e+01,
#        4.50e+01, 4.60e+01, 4.70e+01, 4.80e+01, 4.90e+01, 5.00e+01,
#        5.10e+01, 5.20e+01, 5.30e+01, 5.40e+01, 5.50e+01, 5.60e+01,
#        5.70e+01, 5.80e+01, 5.90e+01, 6.00e+01, 6.10e+01, 6.20e+01,
# ...

# %%
stroke.work_type.sort_values().unique()
# Out:
# array(['Govt_job', 'Never_worked', 'Private', 'Self-employed', 'children'],
#       dtype=object)

# %%
stroke.smoking_status.sort_values().unique()
# Out:
# array(['Unknown', 'formerly smoked', 'never smoked', 'smokes'],
#       dtype=object)

# %%
stroke.isnull().sum(axis=0)
# Out:
# ID                   0
# Gender               0
# Age                  0
# Hypertension         0
# HeartDisease         0
# EverMarried          0
# WorkType             0
# ResidenceType        0
# AvgGlucoseLevel      0
# BMI                201
# SmokingStatus        0
# Stroke               0
# dtype: int64

# %%
sns.countplot( x = 'SmokingStatus', data = stroke, palette="Blues", order=stroke['SmokingStatus'].value_counts().index)
# Out:
# <Axes: xlabel='SmokingStatus', ylabel='count'>

# %%
sns.countplot( x = 'HeartDisease', data = stroke, palette="Blues", order=stroke['HeartDisease'].value_counts().index)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='count'>

# %%
sns.countplot( x = 'Stroke', data = stroke, palette="Blues", order=stroke['Stroke'].value_counts().index)
# Out:
# <Axes: xlabel='Stroke', ylabel='count'>

# %%
sns.countplot( x = 'Hypertension', data = stroke, palette="Blues", order=stroke['Hypertension'].value_counts().index)
# Out:
# <Axes: xlabel='Hypertension', ylabel='count'>

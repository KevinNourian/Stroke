# %% [markdown]
# # **Imports**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import mutual_info_classif
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# # **Functions**

# %%
def read_file(file_path):
    data = pd.read_csv(file_path, index_col=0)

    return data

# %%
def label_encoding(data, column, mapping):
    
    data[column] = data[column].map(mapping)

    return data[column]

# %% [markdown]
# # **Loading Data**

# %%
file_path = r"C:\Users\Space\Documents\py\Projects\TuringCollege\Stroke\Stroke_New\Data\stroke.csv"
data = read_file(file_path)
data = data.drop(columns=['ID'])

# %%
data.head()
# Out:
#    Gender   Age  Hypertension  Heart Disease Ever Married           Work  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   Residence  AVG Glucose   BMI          Smoking  Stroke
# 0     Urban       228.69  36.6  formerly smoked       1
# 1     Rural       202.21   NaN     never smoked       1
# 2     Rural       105.92  32.5     never smoked       1
# 3     Urban       171.23  34.4           smokes       1
# 4     Rural       174.12  24.0     never smoked       1

# %% [markdown]
# # **Divide Data**

# %%
target_column = 'Stroke'
random_seed = 42

# %%
X = data.drop(columns=[target_column])  
y = data[target_column]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=random_seed)

# %% [markdown]
# # **Impute Missing Values**

# %%
from feature_engine.imputation import ArbitraryNumberImputer

# %%
transformer = ArbitraryNumberImputer(
        variables = ['BMI'],
        arbitrary_number = 99
        )
Xt = transformer.fit(X_train)
Xt.transform(X_train)
Xt.transform(X_test)
# Out:
#       Gender   Age  Hypertension  Heart Disease Ever Married           Work  \
# 4688    Male  31.0             0              0           No  Self-employed
# 4478    Male  40.0             0              0          Yes  Self-employed
# 3521    Male  52.0             0              0          Yes        Private
# 4355  Female  79.0             1              0          Yes  Self-employed
# 3826  Female  75.0             0              0          Yes       Govt_job
# ...      ...   ...           ...            ...          ...            ...
# 818     Male  20.0             0              0           No       Govt_job
# 4829    Male  66.0             0              0          Yes        Private
# 611     Male  42.0             0              0          Yes       Govt_job
# 3082  Female  57.0             0              0          Yes        Private
# 3407  Female  60.0             0              0          Yes       Govt_job
#
#      Residence  AVG Glucose   BMI          Smoking
# 4688     Rural        64.85  23.0          Unknown
# 4478     Rural        65.29  28.3     never smoked
# 3521     Rural       111.04  30.0     never smoked
# 4355     Rural        76.64  19.5     never smoked
# 3826     Rural        94.77  27.2     never smoked
# ...        ...          ...   ...              ...
# 818      Rural       106.97  27.9  formerly smoked
# 4829     Rural        67.92  31.1  formerly smoked
# 611      Urban        93.79  27.2     never smoked
# 3082     Rural        69.40  24.0          Unknown
# 3407     Urban        73.04  25.3     never smoked
#
# [1533 rows x 10 columns]

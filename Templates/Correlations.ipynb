# %% [markdown]
# # **Correlations**

# %%
features, mi_scores = mutual_information_classification(data, target_column, random_seed)
plot_mi_scores(features, mi_scores)

# %% [markdown]
# # **Boxplots**

# %%
column_name = 'Age'
lower_limit = -10
upper_limit = 100

plot_boxplot (data, column_name, lower_limit, upper_limit)

# %%
column_name = 'AVG Glucose'
lower_limit = 50
upper_limit = 300

plot_boxplot (data, column_name, lower_limit, upper_limit)

# %%
column_name = 'BMI'
lower_limit = 10
upper_limit = 100

plot_boxplot (data, column_name, lower_limit, upper_limit)
